# %% [markdown]
# # **Name :** Ayush Dattatray Bhagat.

# %% [markdown]
# # Customer Purchase Behavior Analysis using Descriptive Statistics

# %% [markdown]
# ##Problem Statement

# %% [markdown]
# 🔍 **Problem Statement**:
#
# Welcome to the Probability and Statistics project! 📊🔍 In this exciting journey, you'll get the chance to apply the concepts you've learned in probability theory and statistics to analyze a real-world dataset. This project is your opportunity to dive deep into the world of data analysis and gain practical experience with the tools and techniques you've been learning. 🚀
#
# 🎯 **Objective**:
#
# Your mission is to analyze the provided dataset containing customer information and purchasing behavior to make informed decisions. Your goal is to identify patterns, trends, and correlations that will help your company optimize its marketing efforts and increase offer acceptance rates. 🎉

# %% [markdown]
# ##About the Dataset

# %% [markdown]
# Here's the link to the [dataset](https://docs.google.com/spreadsheets/d/12ln9iTNcVNOMYi_AU-OczKpa_KIP8XyVbsjk81Na8Yk/edit?usp=sharing)
#
#
# This data was gathered during last year's campaign.
# Data description is as follows;
#
# 1. Response (target) - 1 if customer accepted the offer in the last campaign, 0 otherwise
# 1. ID - Unique ID of each customer
# 1. Year_Birth - Age of the customer
# 1. Complain - 1 if the customer complained in the last 2 years
# 1. Dt_Customer - date of customer's enrollment with the company
# 1. Education - customer's level of education
# 1. Marital - customer's marital status
# 1. Kidhome - number of small children in customer's household
# 1. Teenhome - number of teenagers in customer's household
# 1. Income - customer's yearly household income
# 1. MntFishProducts - the amount spent on fish products in the last 2 years
# 1. MntMeatProducts - the amount spent on meat products in the last 2 years
# 1. MntFruits - the amount spent on fruits products in the last 2 years
# 1. MntSweetProducts - amount spent on sweet products in the last 2 years
# 1. MntWines - the amount spent on wine products in the last 2 years
# 1. MntGoldProds - the amount spent on gold products in the last 2 years
# 1. NumDealsPurchases - number of purchases made with discount
# 1. NumCatalogPurchases - number of purchases made using catalog (buying goods to be shipped through the mail)
# 1. NumStorePurchases - number of purchases made directly in stores
# 1. NumWebPurchases - number of purchases made through the company's website
# 1. NumWebVisitsMonth - number of visits to company's website in the last month
# 1. Recency - number of days since the last purchase

# %% [markdown]
# ##Task 1 - Basic CleanUp
#
# - **Clean and preprocess the dataset (handling missing values, data types, etc.).**
#
# - **Analyze the distribution of customer demographics (age, education, marital status) using descriptive statistics and visualizations.**

# %% [markdown]
# **Deliverables**:
#
# - **Cleaned and Preprocessed Dataset**:
#
#   Provide a detailed report on the steps taken to handle missing values, including imputation methods used if applicable.
#   Document the process of ensuring consistent data types for each variable, addressing any inconsistencies.
#
# - **Summary of Basic Statistics**:
#
#   Present calculated statistics such as mean, median, variance, and standard deviation for each relevant numerical variable.
#   Include a concise table or summary showcasing these measures for easy reference.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
filepath = '/content/drive/MyDrive/Superstore Marketing Data - Sheet1.csv'

# %%
import numpy as np
import pandas as pd
from scipy.stats import skew, kurtosis
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from scipy.stats import skew
from scipy.stats import kurtosis
from scipy.stats import norm

# %%
df = pd.read_csv(filepath)

# %%
df.head(10)
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
# 5   7348        1958         PhD         Single  71691.0        0         0
# 6   4073        1954    2n Cycle        Married  63564.0        0         0
# 7   1991        1967  Graduation       Together  44931.0        0         1
# 8   4047        1954         PhD        Married  65324.0        0         1
# 9   9477        1954         PhD        Married  65324.0        0         1
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# ...

# %%
df.shape
# Out:
# (2240, 22)

# %%
df.tail(10)
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 2230   3363        1974    2n Cycle        Married  20130.0        0
# 2231   8595        1973  Graduation          Widow  42429.0        0
# 2232   7232        1973  Graduation          Widow  42429.0        0
# 2233   7829        1900    2n Cycle       Divorced  36640.0        1
# 2234   9977        1973  Graduation       Divorced  78901.0        0
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 2230         0   3/17/2014       99         0  ...                7
# 2231         1    ########       99        55  ...                2
# ...

# %%
df.isnull().sum()
# Out:
# Id                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# Response                0
# Complain                0
# dtype: int64

# %%
pd.DataFrame(df[df.isnull().any(axis=1)])
# Out:
#          Id  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 134    8996        1957         PhD        Married     NaN        2         1
# 262    1994        1983  Graduation        Married     NaN        1         0
# 394    3769        1972         PhD       Together     NaN        1         0
# 449    5255        1986  Graduation         Single     NaN        1         0
# 525    8268        1961         PhD        Married     NaN        0         1
# 590   10629        1973    2n Cycle        Married     NaN        1         0
# 899   10475        1970      Master       Together     NaN        0         1
# 997    9235        1957  Graduation         Single     NaN        1         1
# 1096   4345        1964    2n Cycle         Single     NaN        1         1
# 1185   7187        1969      Master       Together     NaN        1         1
# 1213   8720        1978    2n Cycle       Together     NaN        0         0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
df['Dt_Customer'].replace('########',np.nan, inplace=True)

# %%
df.head(10)
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
# 5   7348        1958         PhD         Single  71691.0        0         0
# 6   4073        1954    2n Cycle        Married  63564.0        0         0
# 7   1991        1967  Graduation       Together  44931.0        0         1
# 8   4047        1954         PhD        Married  65324.0        0         1
# 9   9477        1954         PhD        Married  65324.0        0         1
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# ...

# %%
df['Year_Birth'] = pd.to_datetime(df['Year_Birth'], format='%Y')
df['Dt_Customer'] = pd.to_datetime(df['Dt_Customer'])
df["Response"] = df["Response"].astype('object')
df.Complain = df.Complain.astype('object')

# %%
df.rename(columns={'MntWines': 'Amt_Wines', 'MntFruits': 'Amt_Fruits', 'MntMeatProducts': 'Amt_Meat_Products', 'MntFishProducts': 'Amt_Fish_Products', 'MntSweetProducts': 'Amt_Sweet_Products', 'MntGoldProds': 'Amt_Gold_Prods'}, inplace=True)
df.rename(columns={'Recency': 'Last_purchase'}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   datetime64[ns]
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          1324 non-null   datetime64[ns]
#  8   Last_purchase        2240 non-null   int64
#  9   Amt_Wines            2240 non-null   int64
#  10  Amt_Fruits           2240 non-null   int64
#  11  Amt_Meat_Products    2240 non-null   int64
#  12  Amt_Fish_Products    2240 non-null   int64
#  13  Amt_Sweet_Products   2240 non-null   int64
#  14  Amt_Gold_Prods       2240 non-null   int64
# ...

# %%
df.describe().T
# Out:
#                       count                           mean  \
# Id                   2240.0                    5592.159821
# Year_Birth             2240  1968-10-21 16:33:51.428571432
# Income               2216.0                   52247.251354
# Kidhome              2240.0                       0.444196
# Teenhome             2240.0                        0.50625
# Dt_Customer            1324  2013-07-19 09:00:32.628398848
# Last_purchase        2240.0                      49.109375
# Amt_Wines            2240.0                     303.935714
# Amt_Fruits           2240.0                      26.302232
# Amt_Meat_Products    2240.0                         166.95
# Amt_Fish_Products    2240.0                      37.525446
# Amt_Sweet_Products   2240.0                      27.062946
# Amt_Gold_Prods       2240.0                      44.021875
# NumDealsPurchases    2240.0                          2.325
# NumWebPurchases      2240.0                       4.084821
# ...

# %%
null_value = df.isna().sum().sort_values(ascending=False)
null_value
# Out:
# Dt_Customer            916
# Income                  24
# Id                       0
# Amt_Fish_Products        0
# Response                 0
# NumWebVisitsMonth        0
# NumStorePurchases        0
# NumCatalogPurchases      0
# NumWebPurchases          0
# NumDealsPurchases        0
# Amt_Gold_Prods           0
# Amt_Sweet_Products       0
# Amt_Meat_Products        0
# Year_Birth               0
# Amt_Fruits               0
# Amt_Wines                0
# Last_purchase            0
# Teenhome                 0
# Kidhome                  0
# Marital_Status           0
# Education                0
# Complain                 0
# dtype: int64

# %%
fig = px.bar(x=null_value[null_value>0], y=null_value[null_value>0].index)
fig.update_layout(
    title = "Missing value count",
    xaxis_title = "No of missing value",
    yaxis_title = "column name",)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
null_percentage = round((null_value/len(df))*100,2)
null_percentage
# Out:
# Dt_Customer            40.89
# Income                  1.07
# Id                      0.00
# Amt_Fish_Products       0.00
# Response                0.00
# NumWebVisitsMonth       0.00
# NumStorePurchases       0.00
# NumCatalogPurchases     0.00
# NumWebPurchases         0.00
# NumDealsPurchases       0.00
# Amt_Gold_Prods          0.00
# Amt_Sweet_Products      0.00
# Amt_Meat_Products       0.00
# Year_Birth              0.00
# Amt_Fruits              0.00
# Amt_Wines               0.00
# Last_purchase           0.00
# Teenhome                0.00
# Kidhome                 0.00
# Marital_Status          0.00
# Education               0.00
# Complain                0.00
# dtype: float64

# %%
fig = px.bar(x=null_percentage[null_percentage>0], y=null_percentage[null_percentage>0].index)
fig.update_layout(
    title = "Missing value percent",
    xaxis_title = "% of missing value",
    yaxis_title = "column name",)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.drop(columns=['Dt_Customer'], inplace=True)

# %%
df.nunique()
# Out:
# Id                     2240
# Year_Birth               59
# Education                 5
# Marital_Status            8
# Income                 1974
# Kidhome                   3
# Teenhome                  3
# Last_purchase           100
# Amt_Wines               776
# Amt_Fruits              158
# Amt_Meat_Products       558
# Amt_Fish_Products       182
# Amt_Sweet_Products      177
# Amt_Gold_Prods          213
# NumDealsPurchases        15
# NumWebPurchases          15
# NumCatalogPurchases      14
# NumStorePurchases        14
# NumWebVisitsMonth        16
# Response                  2
# Complain                  2
# dtype: int64

# %% [markdown]
# ##Task 2 - Descriptive Statistics 📊
#
# - **Calculate measures of central tendency (mean, median, mode) and measures of dispersion (variance, standard deviation) for key variables. Identify and handle outliers if necessary.**

# %% [markdown]
# **Deliverables**:
#
# - **Descriptive statistics that reveal the central tendencies, variations, and potential outliers in the dataset.**:

# %%
df.dtypes
# Out:
# Id                              int64
# Year_Birth             datetime64[ns]
# Education                      object
# Marital_Status                 object
# Income                        float64
# Kidhome                         int64
# Teenhome                        int64
# Last_purchase                   int64
# Amt_Wines                       int64
# Amt_Fruits                      int64
# Amt_Meat_Products               int64
# Amt_Fish_Products               int64
# Amt_Sweet_Products              int64
# Amt_Gold_Prods                  int64
# NumDealsPurchases               int64
# NumWebPurchases                 int64
# NumCatalogPurchases             int64
# NumStorePurchases               int64
# NumWebVisitsMonth               int64
# Response                       object
# Complain                       object
# dtype: object

# %%
ndf = df.drop(columns=['Education', 'Marital_Status','Year_Birth'])

# %%
print(f'Mean:\n {ndf.mean()}')
# Out:
# Mean:
#  Id                      5592.159821
# Income                 52247.251354
# Kidhome                    0.444196
# Teenhome                    0.50625
# Last_purchase             49.109375
# Amt_Wines                303.935714
# Amt_Fruits                26.302232
# Amt_Meat_Products            166.95
# Amt_Fish_Products         37.525446
# Amt_Sweet_Products        27.062946
# Amt_Gold_Prods            44.021875
# NumDealsPurchases             2.325
# NumWebPurchases            4.084821
# NumCatalogPurchases        2.662054
# NumStorePurchases          5.790179
# NumWebVisitsMonth          5.316518
# Response                   0.149107
# Complain                   0.009375
# dtype: object

# %%
print('median:\n', ndf.median())
# Out:
# median:
#  Id                      5458.5
# Income                 51381.5
# Kidhome                    0.0
# Teenhome                   0.0
# Last_purchase             49.0
# Amt_Wines                173.5
# Amt_Fruits                 8.0
# Amt_Meat_Products         67.0
# Amt_Fish_Products         12.0
# Amt_Sweet_Products         8.0
# Amt_Gold_Prods            24.0
# NumDealsPurchases          2.0
# NumWebPurchases            4.0
# NumCatalogPurchases        2.0
# NumStorePurchases          5.0
# NumWebVisitsMonth          6.0
# Response                   0.0
# Complain                   0.0
# dtype: object

# %%
print('Standard deviation:\n', ndf.std())
# Out:
# Standard deviation:
#  Id                      3246.662198
# Income                 25173.076661
# Kidhome                    0.538398
# Teenhome                   0.544538
# Last_purchase             28.962453
# Amt_Wines                336.597393
# Amt_Fruits                39.773434
# Amt_Meat_Products        225.715373
# Amt_Fish_Products         54.628979
# Amt_Sweet_Products        41.280498
# Amt_Gold_Prods            52.167439
# NumDealsPurchases          1.932238
# NumWebPurchases            2.778714
# NumCatalogPurchases        2.923101
# NumStorePurchases          3.250958
# NumWebVisitsMonth          2.426645
# Response                   0.356274
# Complain                   0.096391
# dtype: object

# %%
print('Variance:\n', ndf.var())
# Out:
# Variance:
#  Id                      10540815.425093
# Income                 633683788.575619
# Kidhome                        0.289873
# Teenhome                       0.296522
# Last_purchase                838.823673
# Amt_Wines                 113297.804709
# Amt_Fruits                  1581.926033
# Amt_Meat_Products          50947.429388
# Amt_Fish_Products           2984.325391
# Amt_Sweet_Products          1704.079555
# Amt_Gold_Prods              2721.441683
# NumDealsPurchases              3.733542
# NumWebPurchases                7.721252
# NumCatalogPurchases            8.544517
# NumStorePurchases             10.568729
# NumWebVisitsMonth              5.888606
# Response                       0.126931
# Complain                       0.009291
# dtype: object

# %%
print('Range:\n', df.select_dtypes('number').max() - df.select_dtypes('number').min())
# Out:
# Range:
#  Id                      11191.0
# Income                 664936.0
# Kidhome                     2.0
# Teenhome                    2.0
# Last_purchase              99.0
# Amt_Wines                1493.0
# Amt_Fruits                199.0
# Amt_Meat_Products        1725.0
# Amt_Fish_Products         259.0
# Amt_Sweet_Products        263.0
# Amt_Gold_Prods            362.0
# NumDealsPurchases          15.0
# NumWebPurchases            27.0
# NumCatalogPurchases        28.0
# NumStorePurchases          13.0
# NumWebVisitsMonth          20.0
# dtype: float64

# %%
df.mode(numeric_only=True).head(1)
# Out:
#    Id  Income  Kidhome  Teenhome  Last_purchase  Amt_Wines  Amt_Fruits  \
# 0   0  7500.0      0.0       0.0           56.0        2.0         0.0
#
#    Amt_Meat_Products  Amt_Fish_Products  Amt_Sweet_Products  Amt_Gold_Prods  \
# 0                7.0                0.0                 0.0             1.0
#
#    NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# 0                1.0              2.0                  0.0                3.0
#
#    NumWebVisitsMonth
# 0                7.0

# %%
print("Skewness:\n", ndf.skew())
# Out:
# Skewness:
#  Id                      0.039832
# Income                  6.763487
# Kidhome                 0.635288
# Teenhome                0.407115
# Last_purchase          -0.001987
# Amt_Wines               1.175771
# Amt_Fruits              2.102063
# Amt_Meat_Products       2.083233
# Amt_Fish_Products       1.919769
# Amt_Sweet_Products      2.136081
# Amt_Gold_Prods          1.886106
# NumDealsPurchases       2.418569
# NumWebPurchases         1.382794
# NumCatalogPurchases     1.880989
# NumStorePurchases       0.702237
# NumWebVisitsMonth       0.207926
# Response                1.971555
# Complain               10.188972
# dtype: object

# %%
print("Kurtosis:\n", ndf.kurtosis())
# Out:
# Kurtosis:
#  Id                      -1.190028
# Income                   159.6367
# Kidhome                 -0.779661
# Teenhome                -0.986235
# Last_purchase           -1.201897
# Amt_Wines                0.598744
# Amt_Fruits               4.050976
# Amt_Meat_Products        5.516724
# Amt_Fish_Products        3.096461
# Amt_Sweet_Products       4.376548
# Amt_Gold_Prods           3.551709
# NumDealsPurchases        8.936914
# NumWebPurchases          5.703128
# NumCatalogPurchases      8.047437
# NumStorePurchases       -0.622048
# NumWebVisitsMonth        1.821614
# Response                 1.888714
# Complain               101.906135
# dtype: object

# %%
df['Total_members'] = df['Kidhome'] + df['Teenhome']
df['Total_spend'] = df['Amt_Fish_Products'] + df['Amt_Fruits'] + df['Amt_Gold_Prods'] + df['Amt_Meat_Products'] + df['Amt_Sweet_Products'] + df['Amt_Wines']

# %%
sns.boxplot(data=df, x='Education', y='Income')
plt.title("Income based on education")
plt.xlabel("Education")
plt.ylabel("Income")
plt.show()

# %%
new_df = df[df['Income'] < 100000]
new_df = new_df[new_df.Year_Birth.astype(int) > 1940]
new_df = new_df.dropna()

new_df = new_df[(new_df['Amt_Wines'] < new_df['Amt_Wines'].quantile(1))]
new_df = new_df[(new_df['Amt_Fruits'] < new_df['Amt_Fruits'].quantile(1))]
new_df = new_df[(new_df['Amt_Meat_Products'] < new_df['Amt_Meat_Products'].quantile(1))]
new_df = new_df[(new_df['Amt_Fish_Products'] < new_df['Amt_Fish_Products'].quantile(1))]
new_df = new_df[(new_df['Amt_Gold_Prods'] < new_df['Amt_Gold_Prods'].quantile(1))]

# %%
sns.boxplot(data=new_df, x='Education', y='Income')
plt.title("Income based on education")
plt.xlabel("Education")
plt.ylabel("Income")
plt.show()

# %%
sns.boxplot(data=new_df, x='Total_members', y='Amt_Wines')
plt.title("Income based on education")
plt.xlabel("Total_members")
plt.ylabel("Amt_Wines")
plt.show()

# %%
sns.boxplot(data=new_df, x='Total_members', y='Amt_Fruits')
plt.title("spending based on members")
plt.xlabel("Total_members")
plt.ylabel("Amt_Fruits")
plt.show()

# %%
sns.boxplot(data=new_df, x='Total_members', y='Amt_Meat_Products')
plt.title("spending based on members")
plt.xlabel("Total_members")
plt.ylabel("Amt_Meat_Products")
plt.show()

# %%
sns.boxplot(data=new_df, x='Total_members', y='Amt_Fish_Products')
plt.title("spending based on members")
plt.xlabel("Total_members")
plt.ylabel("Amt_Fish_Products")
plt.show()

# %%
sns.boxplot(data=new_df, x='Total_members', y='Amt_Sweet_Products')
plt.title("spending based on members")
plt.xlabel("Total_members")
plt.ylabel("Amt_Sweet_Products")
plt.show()

# %%
sns.boxplot(data=new_df, x='Total_members', y='Amt_Gold_Prods')
plt.title("spending based on members")
plt.xlabel("Total_members")
plt.ylabel("Amt_Gold_Prods")
plt.show()

# %%
sns.violinplot(data=new_df, x='Education', y='Income')
plt.title("Income based on education")
plt.xlabel("Education")
plt.ylabel("Income")
plt.show()

# %% [markdown]
# ## Task 3 - Probability Distributions 🎲
#
# - **Identify variables that could follow specific probability distributions (e.g., Binomial, Normal). Calculate probabilities and expected values based on these distributions.**

# %% [markdown]
# **Deliverables**:
#
# - **Determination of suitable probability distributions for relevant variables and corresponding calculated probabilities and expected values.**:

# %%
from scipy.stats import norm
import scipy.stats as stats


mean_incm = new_df['Income'].mean()
std_dev_incm = new_df['Income'].std()


prob = stats.norm.cdf(2) - stats.norm.cdf(-2)

print(f"Expected value: {mean_incm:.2f}, Standard Deviation: {std_dev_incm:.2f}, Probability: {prob:.2f}")
# Out:
# Expected value: 47208.63, Standard Deviation: 21604.40, Probability: 0.95

# %%
new_df['Income'].plot(kind='kde')
plt.xlabel('Income')
plt.ylabel('Density')
plt.title('Income distribution')
plt.show()

stats.probplot(new_df['Income'], dist='norm', plot=plt)
plt.title('Q-Q plot of Income')
plt.show()

# %%
mean_Amt_Wines = new_df['Amt_Wines'].mean()
std_dev_Amt_Wines = new_df['Amt_Wines'].std()

prob = stats.norm.cdf(2) - stats.norm.cdf(-2)

print(f"Expected value: {mean_Amt_Wines:.2f}, Standard Deviation: {std_dev_Amt_Wines:.2f}, Probability: {prob:.2f}")
# Out:
# Expected value: 248.63, Standard Deviation: 321.22, Probability: 0.95

# %%
new_df['Amt_Wines'].plot(kind='kde')
plt.xlabel('Amt_Wines')
plt.ylabel('Density')
plt.title('Amt_Wines distribution')
plt.show()

# Check if Amt_Wines follows a normal distribution
stats.probplot(new_df['Amt_Wines'], dist='norm', plot=plt)
plt.title('Q-Q plot of Amt_Wines')
plt.show()

# %%
mean_Amt_Fruits = new_df['Amt_Fruits'].mean()
std_dev_Amt_Fruits = new_df['Amt_Fruits'].std()


prob = stats.norm.cdf(2) - stats.norm.cdf(-2)

print(f"Expected value: {mean_Amt_Fruits:.2f}, Standard Deviation: {std_dev_Amt_Fruits:.2f}, Probability: {prob:.2f}")
# Out:
# Expected value: 24.43, Standard Deviation: 38.89, Probability: 0.95

# %%
new_df['Amt_Fruits'].plot(kind='kde')
plt.xlabel('Amt_Fruits')
plt.ylabel('Density')
plt.title('Amt_Fruits distribution')
plt.show()


stats.probplot(new_df['Amt_Fruits'], dist='norm', plot=plt)
plt.title('Q-Q plot of Amt_Fruits')
plt.show()

# %%
mean_Amt_Meat_Products = new_df['Amt_Meat_Products'].mean()
std_dev_Amt_Meat_Products = new_df['Amt_Meat_Products'].std()

prob = stats.norm.cdf(2) - stats.norm.cdf(-2)

print(f"Expected value: {mean_Amt_Meat_Products:.2f}, Standard Deviation: {std_dev_Amt_Meat_Products:.2f}, Probability: {prob:.2f}")
# Out:
# Expected value: 150.45, Standard Deviation: 217.93, Probability: 0.95

# %%
new_df['Amt_Meat_Products'].plot(kind='kde')
plt.xlabel('Amt_Meat_Products')
plt.ylabel('Density')
plt.title('Amt_Meat_Products distribution')
plt.show()

stats.probplot(new_df['Amt_Meat_Products'], dist='norm', plot=plt)
plt.title('Q-Q plot of Amt_Meat_Products')
plt.show()

# %%
mean_Amt_Fish_Products = new_df['Amt_Fish_Products'].mean()
std_dev_Amt_Fish_Products = new_df['Amt_Fish_Products'].std()

prob = stats.norm.cdf(2) - stats.norm.cdf(-2)

print(f"Expected value: {mean_Amt_Fish_Products:.2f}, Standard Deviation: {std_dev_Amt_Fish_Products:.2f}, Probability: {prob:.2f}")
# Out:
# Expected value: 34.44, Standard Deviation: 52.76, Probability: 0.95

# %%
new_df['Amt_Fish_Products'].plot(kind='kde')
plt.xlabel('Amt_Fish_Products')
plt.ylabel('Density')
plt.title('Amt_Fish_Products distribution')
plt.show()

stats.probplot(new_df['Amt_Fish_Products'], dist='norm', plot=plt)
plt.title('Q-Q plot of Amt_Fish_Products')
plt.show()

# %%
mean_Amt_Sweet_Products = new_df['Amt_Sweet_Products'].mean()
std_dev_Amt_Sweet_Products = new_df['Amt_Sweet_Products'].std()

prob = stats.norm.cdf(2) - stats.norm.cdf(-2)

print(f"Expected value: {mean_Amt_Sweet_Products:.2f}, Standard Deviation: {std_dev_Amt_Sweet_Products:.2f}, Probability: {prob:.2f}")
# Out:
# Expected value: 25.92, Standard Deviation: 40.80, Probability: 0.95

# %%
new_df['Amt_Sweet_Products'].plot(kind='kde')
plt.xlabel('Amt_Sweet_Products')
plt.ylabel('Density')
plt.title('Amt_Sweet_Products distribution')
plt.show()

# Check if Amt_Sweet_Products follows a normal distribution
stats.probplot(new_df['Amt_Sweet_Products'], dist='norm', plot=plt)
plt.title('Q-Q plot of Amt_Sweet_Products')
plt.show()

# %%
mean_Amt_Gold_Prods = new_df['Amt_Gold_Prods'].mean()
std_dev_Amt_Gold_Prods = new_df['Amt_Gold_Prods'].std()

prob = stats.norm.cdf(2) - stats.norm.cdf(-2)

print(f"Expected value: {mean_Amt_Gold_Prods:.2f}, Standard Deviation: {std_dev_Amt_Gold_Prods:.2f}, Probability: {prob:.2f}")
# Out:
# Expected value: 39.08, Standard Deviation: 48.05, Probability: 0.95

# %%
new_df['Amt_Gold_Prods'].plot(kind='kde')
plt.xlabel('Amt_Gold_Prods')
plt.ylabel('Density')
plt.title('Amt_Gold_Prods distribution')
plt.show()

# Check if Amt_Gold_Prods follows a normal distribution
stats.probplot(new_df['Amt_Gold_Prods'], dist='norm', plot=plt)
plt.title('Q-Q plot of Amt_Gold_Prods')
plt.show()

# %%
for col in new_df.columns:
  if new_df[col].dtype == 'object':
    continue
  sns.histplot(new_df[col], kde=True)
  plt.title(f'Skewness of {col}')
  plt.xlabel(col)
  plt.ylabel('frequency')
  plt.show()

# %% [markdown]
# ## Task 4: Insights and Customer Segmentation 📈
#
# - **Explore relationships between customer characteristics and spending habits. Segment customers based on their behaviors and characteristics.**

# %% [markdown]
# **Deliverables**:
#
# - **Key insights regarding relationships between variables and distinct customer segments based on behaviors.**

# %%
plt.pie(new_df['Education'].value_counts(), labels=new_df['Education'].value_counts().index, autopct='%1.1f%%')
plt.title('Pie chart of Education')
plt.show()

# %%
plt.pie(new_df['Marital_Status'].value_counts(), labels=new_df['Marital_Status'].value_counts().index, autopct='%1.1f%%')
plt.title('Pie chart of Marital_Status')
plt.show()

# %%
plt.pie(new_df['Response'].value_counts(), labels=new_df['Response'].value_counts().index, autopct='%1.1f%%')
plt.title('Pie chart of Response')
plt.show()

# %%
plt.pie(new_df['Complain'].value_counts(), labels=new_df['Complain'].value_counts().index, autopct='%1.1f%%')
plt.title('Pie chart of Complain')
plt.show()

# %%
sns.scatterplot( x=new_df['Income'], y=new_df['Total_spend'], data=new_df, hue='Response')
plt.xlabel('Income')
plt.ylabel('Total_spend')
plt.title('Scatter plot of Income vs Total_spend')
plt.show()

# %%
spending = new_df[['Amt_Wines', 'Amt_Fruits', 'Amt_Meat_Products', 'Amt_Fish_Products', 'Amt_Sweet_Products', 'Amt_Gold_Prods']]

purchasing = new_df[['NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases']]

# %%
for col in spending:
  if new_df[col].dtype == 'object':
    continue
  sns.barplot(x=new_df['Total_members'], y=new_df[col])
  plt.title(f'plot bw {col} & Total_members')
  plt.xlabel('Total_members')
  plt.ylabel(col)
  plt.show()

# %%
for col in spending:
  if new_df[col].dtype == 'object':
    continue
  sns.barplot(x=new_df['Kidhome'], y=new_df[col])
  plt.title(f'plot bw {col} & Kidhome')
  plt.xlabel('Kidhome')
  plt.ylabel(col)
  plt.show()

# %%
for col in spending:
  if new_df[col].dtype == 'object':
    continue
  sns.barplot(x=new_df['Teenhome'], y=new_df[col])
  plt.title(f'{col} consumption based on Teenhome')
  plt.xlabel('Teenhome')
  plt.ylabel(col)
  plt.show()

# %%
for col in spending:
  if new_df[col].dtype == 'object':
    continue
  sns.barplot(x=new_df['Education'], y=new_df[col])
  plt.title(f'{col} consumption based on education')
  plt.xlabel('Education')
  plt.ylabel(col)
  plt.show()

# %%
for col in spending:
  if new_df[col].dtype == 'object':
    continue
  sns.lineplot(x=new_df['Year_Birth'], y=new_df[col])
  plt.title(f'{col} consumption based on Year_Birth')
  plt.xlabel('Year_Birth')
  plt.ylabel(col)
  plt.show()

# %%
for col in purchasing:
  sns.barplot(x=new_df[col], y=new_df['Total_spend'])
  plt.title(f'Relation bw {col} & Total_spend')
  plt.xlabel(col)
  plt.ylabel('Total_spend')
  plt.show()

# %%
new_df.groupby(['Marital_Status', 'Response']).size().unstack().plot(kind='bar', stacked=True)
plt.xlabel('Marital_Status')
plt.ylabel('Count')
plt.title('Stacked bar graph of Marital_Status and Response')
plt.show()

# %%
sns.scatterplot( x=new_df['Income'], y=new_df['Marital_Status'], data=new_df, hue='Response')
plt.xlabel('Income')
plt.ylabel('Marital_Status')
plt.title('Scatter plot of Income vs Total_spend')
plt.show()

# %% [markdown]
# ## Task 5: Conclusion and Recommendations
#
# - **Create clear visualizations to showcase your findings. Use insights to make recommendations for the company based on your analysis.**

# %% [markdown]
# **Deliverables**:
#
# - **Well-designed visualizations that visually represent your insights and actionable recommendations based on customer behavior analysis.**

# %% [markdown]
# ## Colclusion

# %% [markdown]
# **Expected value & Standard Deviation**
#
#
# *   Income - Expected value: 47208.63, Standard Deviation: 21604.40
#
# *   Amt_Wines - Expected value: 248.63, Standard Deviation: 321.22
#
# *   Amt_Fruits - Expected value: 24.43, Standard Deviation: 38.89
#
# *   Amt_Meat_Products - Expected value: 150.45, Standard Deviation: 217.93
# *   Amt_Fish_Products - Expected value: 34.44, Standard Deviation: 52.76
#
#
# *   Amt_Sweet_Products - Expected value: 25.92, Standard Deviation: 40.80
#
#
# * Amt_Gold_Prods- Expected value: 39.08, Standard Deviation: 48.05

# %% [markdown]
#  **Skewness and data distribution**
#
#
#
# *   id - uniform distribution
# *   Year_of_birth - right skewed, peack - 160
#
# *   Income - right skewed, peack - 160
#
# *   Last_purchase - uniform distribution, peack - 160
#
# *   Amt_wines - right skewed, peack - 500
#
# *   Amt_Fruit - right skewed, peack - 430
# *   Amt_Meat_Products - right skewed, peack - 480
#
#
# *  Amt_Fish_Products - right skewed, peack - 450
#
#
# *   Amt_Gold_Products - right skewed, peack - 250
#
#
# *   Amt_Sweet_Products - right skewed, peack - 470

# %% [markdown]
# **Sales Mode**
#
#
#
# * Deals purchase - right skewed, peack - 500
# * Web purchase - right skewed, peack - 200
# * Catalog purchase - right skewed, peack - 350
# * Store purchase - right skewed, peack - 300

# %% [markdown]
# * In Dataset most of the people are graduates(51%) & phd(18%)
# * Most of the people are in married,Together or single Marital_Status category
# * Only 15.7 % people give positive responce
# * Only 0.9 % people registor complaints
# * Spending increase as Income increase, people with High Income & spending have more positive responce
# * As total member increase ammount spend decrease
# * Amount spend decrease when kids in home increase
# * Amount spend on wine and gold increase when teen increase remaining things decrease
# * Total spending increase With the no of purchase

# %% [markdown]
# **Recommendations:**
#
# * Targate graduate & phd professionals more
# * Targate people which have high Income and High spending habits
# * Offer on wine & gold to those customers who have more teens in house
# * Give more offers to people with no teen and kids in house
# * Give offers to old regular customers

# %% [markdown]
# ## Bonus Task - Geogebra Experiment

# %% [markdown]
# Here's the link to an intriguing GeoGebra experiment: [GeoGebra Experiment Link](https://www.geogebra.org/m/LZbwMZtJ)
#
# This experiment lets you simulate coin flips as per your preferences and specifications!
#
# Your task involves recording a video where you'll explain the concept of the **Law of Large Numbers** using this experiment. Dive further into the experience by adjusting the number of coins and exploring varying coin biases. 🪙📹🔍
